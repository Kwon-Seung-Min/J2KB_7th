# %% [markdown]
# # 🚀6주차 2단계 : Python 시각화 Tool 찍먹하기🚀

# %% [markdown]
# ## 학습 참고 자료

# %% [markdown]
# - 활용 코드 : **https://colab.research.google.com/notebooks/charts.ipynb#scrollTo=cRkuifc7PazR**
# - Seaborn : **https://blog.naver.com/nach3012/222427545163**
# - Altair : **https://minwook-shin.github.io/python-declarative-statistical-visualization-using-altair/**
# - Plotly : **https://dailyheumsi.tistory.com/118**, **https://zephyrus1111.tistory.com/154**
# - Bokeh : **https://blog.naver.com/dnlee119/222672348684**

# %% [markdown]
# ## Seaborn

# %% [markdown]
# - 1단계에서 다뤘던 matplotlib에 비해 훨씬 간편하고, 시각적으로 아름답다.
# - matplotlib과 기본 문법 구조는 비슷하다.

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Generate some random data
num_points = 20
# x will be 5, 6, 7... but also twiddled randomly
x = 5 + np.arange(num_points) + np.random.randn(num_points)
# y will be 10, 11, 12... but twiddled even more randomly
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)
sns.regplot(x, y)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Make a 10 x 10 heatmap of some random data
side_length = 10
# Start with a 10 x 10 matrix with values randomized around 5
data = 5 + np.random.randn(side_length, side_length)
# The next two lines make the values larger as we get closer to (9, 9)
data += np.arange(side_length)
data += np.reshape(np.arange(side_length), (side_length, 1))
# Generate the heatmap
sns.heatmap(data)
plt.show()

# %% [markdown]
# ## Altair

# %% [markdown]
# - Vega 및 Vega-Lite에 기반한 Python용 선언적 통계 시각화 라이브러리이다.
# - 데이터의 의미를 이해하는 데 시간을 많이 들이고자 할 때 사용한다.
# - Altair의 API는 일관성이 있는 Vega-Lite 문법 위에 구축되었다.
# - 최소한의 코드로 아름다운 시각화를 만들어낼 수 있는 도구이다.
# - **Jupiter Notebook에서 Altair를 사용하려면 vega 패키지의 우선 설치가 필요하다.**
# - Jupiter Notebook으로 다양한 블로그를 통해 Altair 설치를 시도했지만, 모두 실패했다 ㅠㅠ

# %% [markdown]
# ## Plotly

# %% [markdown]
# - 위에서 살펴본 시각화 툴보다 훨씬 더 세련되게 시각화를 해주는 툴이라고 한다.
# - 웹 시각화 라이브러리인 d3.js를 이용하여 보다 interactive하게 그래프를 만들어 준다.
# - **cufflinks만 설치해도 나머지 관련 라이브러리들을 최신 버전으로 함께 받을 수 있다. (대신 시간이 꽤 소요된다)**
# - 상단의 참고자료 중 순서상 첫번째 링크를 따라서만 진행하면 오류가 발생하는데, 이 부분은 chart studio의 모듈 설치 및 사용을 수반하기 때문에 해당 사이트(**https://chart-studio.plotly.com/**) 회원가입을 한 뒤, 순서상 두번째 링크에서 소개하는 절차에 따라 진행해야 한다.

# %%
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68734 sha256=a8db277a9acdcee73039dc66b9ec62dfaa8ccce796714a276ce6d193777e1b62
#   Stored in directory: c:\users\alra\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
# !pip install chart_studio
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=07dcc2f892e0c937324af731c38b83784d4d269054c69e64576d291eed30debf
#   Stored in directory: c:\users\alra\appdata\local\pip\cache\wheels\ce\18\7f\e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...

# %%
# 근데 Google Colab 예제는 잘 돌아가네요.. ㅠㅠ
# 마치 등고선 같은..
from plotly.offline import iplot
import plotly.graph_objs as go

data = [
    go.Contour(
        z=[[10, 10.625, 12.5, 15.625, 20],
           [5.625, 6.25, 8.125, 11.25, 15.625],
           [2.5, 3.125, 5., 8.125, 12.5],
           [0.625, 1.25, 3.125, 6.25, 10.625],
           [0, 0.625, 2.5, 5.625, 10]]
    )
]
iplot(data)
# Out:
# <div>                            <div id="d627a136-d7fc-480a-8163-f1660e584006" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d627a136-d7fc-480a-8163-f1660e584006")) {                    Plotly.newPlot(                        "d627a136-d7fc-480a-8163-f1660e584006",                        [{"z":[[10,10.625,12.5,15.625,20],[5.625,6.25,8.125,11.25,15.625],[2.5,3.125,5.0,8.125,12.5],[0.625,1.25,3.125,6.25,10.625],[0,0.625,2.5,5.625,10]],"type":"contour"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5
# ...

# %% [markdown]
# ## Bokeh

# %% [markdown]
# - Matplotlib와는 다르게 자체적으로 HTML 파일로 만들어 그래프를 늘리거나 줄이거나 했을 때, 기본적인 Matplotlib의 png 파일보다 질 높은 결과를 가져온다.
# - 품질이 높은 만큼 용량도 크게 차지하므로 유의하자.

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
N = 3000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x).astype(int), np.floor(30+2*y).astype(int))]

p = figure()
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
show(p)
# Out:
#   <div class="bk-root" id="0674ebd1-34da-4744-9314-920f155c0599" data-root-id="1003"></div>

# %%
# N의 값만 2배로 늘려서 다시 2차 출력
N = 6000
x = np.random.random(size=N) * 100
y = np.random.random(size=N) * 100
radii = np.random.random(size=N) * 1.5
colors = ["#%02x%02x%02x" % (r, g, 150) for r, g in zip(np.floor(50+2*x).astype(int), np.floor(30+2*y).astype(int))]

p = figure()
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
show(p)
# Out:
#   <div class="bk-root" id="d3ac9469-a865-4f5b-8bc5-325c345afd3a" data-root-id="1106"></div>
