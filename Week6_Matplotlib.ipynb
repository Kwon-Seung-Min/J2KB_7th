# %% [markdown]
# # 🚀6주차 1단계 : Matplotlib, Pyplot 기초🚀

# %% [markdown]
# ## 학습 참고 자료

# %% [markdown]
# https://blog.naver.com/nkj2001/222699180076

# %% [markdown]
# ## Import

# %% [markdown]
# **아래 코드를 돌려서, 일단 matplotlib 라이브러리를 설치할 수 있다.**
#
# 필자는 Requirement already satisfied 구문이 나온 것으로 보아, 설치가 이미 되어있음을 알 수 있다.

# %%
# !pip install matplotlib

# %% [markdown]
# 이제, pyplot을 사용하기 위해 다음과 같이 입력한다.
#
# matplotlb.pyplot을 앞으로의 코드에서 계속 일일이 작성하기 번거로우니, **as를 활용하여 짧게 약칭해 plt로 표현하겠다.**

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 실제 그래프는 pyplot을 이용하여 그리게 된다. 아래 예시 코드를 돌려서 확인해 보자.
#
# 돌려 보면, 하나의 직선이 출력되는데, 이는 다섯 개의 point를 하나로 이은 직선을 표현한 것이다. **(점 다섯 개로 표현되지 않는다!)**

# %%
plt.plot([1, 2, 3, 4, 5], [1, 1.5, 2, 2.5, 3])
plt.show()

# %% [markdown]
# 조금 더 알아보자.

# %%
plt.plot([1, 2, 3, 4, 5], [1, 1.5, 2, 2.5, 3])
plt.xlabel("X_increase")
plt.ylabel("Y_increase")
plt.title("test graph")
plt.legend(["SAMPLE"])
plt.show()

# %% [markdown]
# xlabel, ylabel을 통해 그래프의 x축, y축에 라벨을 표시해줄 수 있다.
#
# title 함수를 통해 그래프의 제목을 상단에 명시할 수 있다.
#
# legend 함수를 통해 그어진 그래프의 범례를 표시해줄 수 있다.

# %% [markdown]
# ## Matplotlib pyplot Marker

# %% [markdown]
# pyplot의 plot 함수에는 다양한 marker style을 적용할 수 있다.
#
# 자세한 내용은 상단 학습 참고자료에 나와 있다.

# %% [markdown]
# ## Matplotlib pyplot Line Style

# %% [markdown]
# pyplot의 plot 함수에는 다양한 line style을 적용할 수 있다.
#
# 역시 자세한 내용은 상단 학습 참고자료에 나와 있다.

# %% [markdown]
# ## Matplotlib pyplot Colors

# %% [markdown]
# pyploy의 plot 함수에는 그래프에 다양한 색상을 적용할 수 있다.
#
# 역시 자세한 내용은 상단 학습 참고자료에 나와 있다.

# %% [markdown]
# ## 포맷스트링 형식의 사용 (pyplot 그래프의 속성 : Marker, Line Style, Colors 활용)

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.plot.html

# %% [markdown]
# - 예시로 **k-.v**는 검정색 대쉬닷 라인 스타일을 가진 그래프를 그리고, 핵심 원소에 역삼각형의 마커를 찍어 표시하도록 한다는 의미이다.

# %%
plt.plot([1, 1.25, 1.5, 1.75, 2], [1, 1.5, 2, 2.5, 3], "k-.v")
plt.plot([1, 3, 6, 10, 15], [1, 2, 3, 4, 5], "h:r")
plt.xlabel("X_increase")
plt.ylabel("Y_increase")
plt.title("test graph")
plt.legend(["A", "B"])
plt.show()

# %% [markdown]
# ## Matplotlib에서 한글을 표시하는 방법

# %% [markdown]
# Matplotlib에서 한글을 사용하기 위해서는, 사용할 폰트를 미리 지정해주어야 한다.

# %%
# 맑은고딕 글꼴을 적용
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
plt.plot([1, 1.25, 1.5, 1.75, 2], [1, 1.5, 2, 2.5, 3], "k-.v")
plt.plot([1, 3, 6, 10, 15], [1, 2, 3, 4, 5], "h:b")
plt.xlabel("X 축")
plt.ylabel("Y 축")
plt.title("하나의 영역에 두 개의 그래프 동시에 그리기")
plt.legend(["A 그래프", "B 그래프"])
plt.show()

# %% [markdown]
# ## Matplotlib에서 막대그래프 그리기

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# %%
def barplot():
    plt.bar([1, 2, 3, 4, 5], [10, 15, 25, 40, 60], color="green", width=0.5, antialiased=True, fill=True)
    plt.xlabel("X 축")
    plt.ylabel("Y 축")
    plt.title("막대그래프 그리기")
    plt.legend(["A 그래프", "B 그래프"])
    plt.show()

barplot()

# %% [markdown]
# ## Matplotlib에서 원형그래프 그리기

# %% [markdown]
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.pie.html

# %%
def piegraph():
    plt.pie([10, 20, 30, 40], labels=['A', 'B', 'C', 'D'], shadow=False, colors=['red', 'yellow', 'green', 'magenta'], autopct='%.2f%%')
    plt.xlabel("X 축")
    plt.ylabel("Y 축")
    plt.title("원형그래프 그리기")
    plt.legend(["A 그래프", "B 그래프", "C 그래프", "D 그래프"])
    plt.show()

piegraph()
